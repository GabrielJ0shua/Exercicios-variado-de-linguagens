# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia.csv", sep=",", parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df.loc[:,:]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.loc[[1,6]]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 6              40215               40215                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1             BELÉM            PA                 SBBE     03/01/2010
# 6             COARI            AM                 SBUY     07/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 1        11:05:00                   0
# 6        18:40:00                   0

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 1        11:05:00                   0
# 2        03:00:00                   0
# 3        17:30:00                   0

# %%
df.loc[1:10,'ocorrencia_cidade']
# Out:
# 1                  BELÉM
# 2         RIO DE JANEIRO
# 3     LUCAS DO RIO VERDE
# 4                PELOTAS
# 5               SALVADOR
# 6                  COARI
# 7               CANUTAMA
# 8               CASCAVEL
# 9          PARÁ DE MINAS
# 10      SÃO PEDRO DO SUL
# Name: ocorrencia_cidade, dtype: object

# %%
df['ocorrencia_uf'].unique()
# Out:
# array(['RJ', 'PA', 'MT', 'RS', 'BA', 'AM', 'PR', 'MG', 'SP', 'DF', 'AC',
#        'TO', 'SC', 'GO', 'MA', 'ES', 'PE', 'RR', 'MS', 'CE', 'AP', 'AL',
#        'RO', 'SE', 'PB', 'PI', 'RN', '***', '890274583', '87', '82439',
#        '6372222', 'PELOTAS', '6530', '1408920', '4780', '13666', '3705',
#        '25234', '37', '961388', '261337', '605000', '475519', '1722687',
#        '20083', '469226', '9186', '2528'], dtype=object)

# %%
df.codigo_ocorrencia2.is_unique
#df.set_index('codigo_ocorrencia', inplace=True)
#df.reset_index(drop=True, inplace=True)
# Out:
# True

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 6109               80245                INCIDENTE              RECIFE
# 6110               80247                INCIDENTE         PORTO VELHO
# 6111               80251                INCIDENTE               BELÉM
# 6112               80257                 ACIDENTE          DOM AQUINO
# 6113               80259                INCIDENTE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.loc[df.ocorrencia_dia]
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 6109               80245                INCIDENTE              RECIFE
# 6110               80247                INCIDENTE         PORTO VELHO
# 6111               80251                INCIDENTE               BELÉM
# 6112               80257                 ACIDENTE          DOM AQUINO
# 6113               80259                INCIDENTE            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.replace(["**", "!****", "****", "NULL"], pd.NA, inplace=True)# Onde ocorrer a lista, ele vai alterar.

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2263
# ocorrencia_dia                 1
# ocorrencia_hora                9
# total_recomendacoes            1
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.drop(['nome_da_coluna'], axis=1)#axis =1 coluna, axis = 0 linha
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c9cd119b3e5c> in <module>
# ----> 1 df.drop(['nome_da_coluna'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.dropna(subset=['nome_da_coluna'], inplace=True)
df.drop_duplicates(inplace=True)
